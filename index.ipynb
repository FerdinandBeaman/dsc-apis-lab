# %% [markdown]
# # APIs - Cumulative Lab
#
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API.
#
# ## Objectives
#
# You will be able to:
#
# * Practice using functions to organize your code
# * Use pagination to retrieve all results from an API query
# * Practice parsing data returned from an API query
# * Practice interpreting visualizations of a dataset
# * Create maps using Folium

# %% [markdown]
# ## Your Task: Query Yelp for All Businesses in a Category and Analyze the Results
#
# ![restaurant counter with pizza](images/restaurant_counter.jpg)
#
# Photo by <a href="https://unsplash.com/@jordanmadrid?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Jordan Madrid</a> on <a href="/s/photos/pizza-restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Overview
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. In this lab, you will write a query of businesses on Yelp, then use *pagination* to retrieve all possible results for that query. Then you will create a summary of your findings, including a Folium map of the geographic locations of those businesses.
#
# ### Technical Details
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the **API limits**. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a **maximum of 50 results per request** and defaults to 20. Furthermore, any search will be limited to a **total of 1000 results**. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# Also, be mindful of the **API** ***rate*** **limits**. You can only make **5000 requests per day** and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use `time.sleep(n)` to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a list of dictionaries (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ### Requirements
#
# #### 1. Make the Initial Request
#
# Start by filling in your API key to make the initial request to the business search API. Investigate the structure of the response you get back and start figuring out how you will extract the relevant information.
#
# #### 2. Add Pagination
#
# Using loops and functions, collect the maximum number of results for your query from the API.
#
# #### 3. Perform Exploratory Analysis
#
# Interpret visualizations related to the price range, average rating, and number of reviews for all query results.
#
# #### 4. Create a Folium Map
#
# Using latitude and longitude data, plot the query results on an interactive map.

# %% [markdown]
# ## 1. Make the Initial Request
#
# ### Querying
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.
#
# Use the `requests` library ([documentation here](https://requests.readthedocs.io/en/master/user/quickstart/#make-a-request)).
#
# You'll also need an API key from Yelp. If you haven't done this already, go to the Yelp [Manage App page](https://www.yelp.com/developers/v3/manage_app) and create a new app (after making an account if you haven't already).

# %%
# Replace None with appropriate code

# Import the requests library
import requests

# Get this from the "Manage App" page. Make sure you set them
# back to None before pushing this to GitHub, since otherwise
# your credentials will be compromised
api_key = "nyahnya"

# These can be whatever you want! But the solution uses "pizza"
# and "New York NY" if you want to compare your work directly
term = "Pizza"
location = "New York NY"

# Set up params for request
url = "https://api.yelp.com/v3/businesses/search"
headers = {
    "Authorization": "Bearer {}".format(api_key)
}
url_params = {
    "term": term.replace(" ", "+"),
    "location": location.replace(" ", "+")
}

# Make the request using requests.get, passing in
# url, headers=headers, and params=url_params
response = requests.get(url, headers=headers, params=url_params)

# Confirm we got a 200 response
response.status_code
# Out:
# 200

# %%
# Run this cell without changes

# Get the response body in JSON format
response_json = response.json()
# View the keys
response_json.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# ### Extracting Data
#
# Now, retrieve the value associated with the `'businesses'` key, and inspect its contents.

# %%
response.json()["businesses"]
# Out:
# [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#   'alias': 'prince-street-pizza-new-york-2',
#   'name': 'Prince Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PfI8oV4ct9ZJZNtUhSS8DQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 4839,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.72308755605564,
#    'longitude': -73.99453001177575},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '27 Prince St',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['27 Prince St', 'New York, NY 10012']},
#   'phone': '+12129664100',
#   'display_phone': '(212) 966-4100',
#   'distance': 2209.3116178604555},
#  {'id': 'ysqgdbSrezXgVwER2kQWKA',
#   'alias': 'julianas-brooklyn-3',
#   'name': "Juliana's",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NVoLFle5H-SHNN6piAKIYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 2626,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70274718768062,
#    'longitude': -73.99343490196397},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Old Fulton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#   'phone': '+17185966700',
#   'display_phone': '(718) 596-6700',
#   'distance': 1289.8572856708206},
#  {'id': 'WG639VkTjmK5dzydd1BBJA',
#   'alias': 'rubirosa-new-york-2',
#   'name': 'Rubirosa',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/F65qqO1RNThFSHKKJ4iTRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 2972,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.722766, 'longitude': -73.996233},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '235 Mulberry St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#   'phone': '+12129650500',
#   'display_phone': '(212) 965-0500',
#   'distance': 2268.491949505166},
#  {'id': 'WIhm0W9197f_rRtDziq5qQ',
#   'alias': 'lombardis-pizza-new-york-4',
#   'name': "Lombardi's Pizza",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m_9TT6hSasEMQKjvImPZGw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 6558,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7215934960083,
#    'longitude': -73.9955956044561},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '32 Spring St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10012',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Spring St', 'New York, NY 10012']},
#   'phone': '+12129417994',
#   'display_phone': '(212) 941-7994',
#   'distance': 2133.973859305024},
#  {'id': 'uc5qQMzs96rzjK27epDCug',
#   'alias': 'joes-pizza-new-york-4',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 2995,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73060076, 'longitude': -74.00215997},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '7 Carmine St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['7 Carmine St', 'New York, NY 10014']},
#   'phone': '+12123661182',
#   'display_phone': '(212) 366-1182',
#   'distance': 3263.1741429829735},
#  {'id': 'v1DHGRNCH9247WLYoaoA9A',
#   'alias': 'l-industrie-pizzeria-brooklyn',
#   'name': "L'industrie Pizzeria",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/KKB2Trak1Ou3bqJePe8RmQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 922,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '254 S 2nd St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#   'phone': '+17185990002',
#   'display_phone': '(718) 599-0002',
#   'distance': 1868.2955120772579},
#  {'id': 'KEEXuHCYhsQJ-zpJhu98bA',
#   'alias': 'joes-pizza-new-york-148',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VkqlwRNIlHO68gTUC7p6wQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-148?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 1856,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7547, 'longitude': -73.98696},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1435 Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10018',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1435 Broadway', 'New York, NY 10018']},
#   'phone': '+16465594878',
#   'display_phone': '(646) 559-4878',
#   'distance': 5345.19242853166},
#  {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#   'alias': 'johns-of-bleecker-street-new-york-2',
#   'name': "John's of Bleecker Street",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/r2bmU0uH-6SSxqjRbITDgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 2535,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '278 Bleecker St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#   'phone': '+12122431680',
#   'display_phone': '(212) 243-1680',
#   'distance': 3418.683385703463},
#  {'id': '2ggi1luerd3Mf_C82JvCYg',
#   'alias': 'grimaldis-pizzeria-brooklyn-4',
#   'name': "Grimaldi's Pizzeria",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Ek1cwe4Dh74lu2P4BgHsFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/grimaldis-pizzeria-brooklyn-4?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 4919,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.7026459, 'longitude': -73.9932413},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1 Front St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11201',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1 Front St', 'Brooklyn, NY 11201']},
#   'phone': '+17188584300',
#   'display_phone': '(718) 858-4300',
#   'distance': 1278.875725593207},
#  {'id': 'Q9F2ocrmYuGt1yn3M7MOBw',
#   'alias': 'lucali-brooklyn-3',
#   'name': 'Lucali',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Yl_eZ_DW_iaumnU-pfSoaw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucali-brooklyn-3?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 1950,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.681840746711224, 'longitude': -74.0003327},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '575 Henry St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11231',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['575 Henry St', 'Brooklyn, NY 11231']},
#   'phone': '+17188584086',
#   'display_phone': '(718) 858-4086',
#   'distance': 3315.2311894952527},
#  {'id': 'MwcRbM6lS6_8N67LmyBELA',
#   'alias': '99-cent-fresh-pizza-new-york-5',
#   'name': '99 Cent Fresh Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6v8b4OPmR5-qcnfloO5jSQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/99-cent-fresh-pizza-new-york-5?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 684,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.76458, 'longitude': -73.98247},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '1723 Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10019',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1723 Broadway', 'New York, NY 10019']},
#   'phone': '+12122452155',
#   'display_phone': '(212) 245-2155',
#   'distance': 6414.231405412516},
#  {'id': 'pGr5QuQU7Ur5GHLvXbT8bw',
#   'alias': 'paulie-gees-brooklyn',
#   'name': "Paulie Gee's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RCrEpYm1HSV3McDJIwq5Uw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paulie-gees-brooklyn?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 1340,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.729546, 'longitude': -73.958568},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '60 Greenpoint Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['60 Greenpoint Ave', 'Brooklyn, NY 11222']},
#   'phone': '+13479873747',
#   'display_phone': '(347) 987-3747',
#   'distance': 3047.8912503861025},
#  {'id': '16ZnHpuaaBt92XWeJHCC5A',
#   'alias': 'olio-e-più-new-york-7',
#   'name': 'Olio e Più',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nn4I1SG0pYmqCyJPlArYOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olio-e-pi%C3%B9-new-york-7?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 4247,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.733798036104304,
#    'longitude': -73.99977392649927},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '3 Greenwich Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['3 Greenwich Ave', 'New York, NY 10014']},
#   'phone': '+12122436546',
#   'display_phone': '(212) 243-6546',
#   'distance': 3450.228657989248},
#  {'id': '4h4Tuuc56YPO6lWfZ1bdSQ',
#   'alias': 'joes-pizza-new-york-152',
#   'name': "Joe's Pizza",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dxFrYV5dwtAg0TAPs7CpEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joes-pizza-new-york-152?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 448,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7101297729083,
#    'longitude': -74.0077206864953},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '124 Fulton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10038',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['124 Fulton St', 'New York, NY 10038']},
#   'phone': '+12122670860',
#   'display_phone': '(212) 267-0860',
#   'distance': 2430.5013066890315},
#  {'id': 'MphfKkYFEe0BDQ6hZ0A5fA',
#   'alias': 'gelso-and-grand-new-york',
#   'name': 'Gelso & Grand',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZV0bgSfrkjlb1rewpItqCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gelso-and-grand-new-york?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 1387,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.71958, 'longitude': -73.99734},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '186 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10013',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['186 Grand St', 'New York, NY 10013']},
#   'phone': '+12122261600',
#   'display_phone': '(212) 226-1600',
#   'distance': 2076.0405590641603},
#  {'id': 'FhXjAc6nKLf414KxYujUHw',
#   'alias': 'robertas-brooklyn-2',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8fY9fA5TtCF0ebdTNph9mQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-brooklyn-2?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 3258,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70493, 'longitude': -73.93399},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '261 Moore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Moore St', 'Brooklyn, NY 11206']},
#   'phone': '+17184171118',
#   'display_phone': '(718) 417-1118',
#   'distance': 3816.592614864351},
#  {'id': '6ECcDYsRgmfv0eKXk-c11Q',
#   'alias': 'la-nonna-krispy-krust-pizza-brooklyn',
#   'name': 'La Nonna Krispy Krust Pizza',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/fVNfYkz-16i-QNIMfud6RA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/la-nonna-krispy-krust-pizza-brooklyn?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 74,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.717953, 'longitude': -73.9637027},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '175 Kent Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['175 Kent Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13473842100',
#   'display_phone': '(347) 384-2100',
#   'distance': 1786.793378712152},
#  {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#   'alias': 'bleecker-street-pizza-new-york',
#   'name': 'Bleecker Street Pizza',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/eyWJGpyVVgii2MYkyB2bkA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 2809,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7320627016512,
#    'longitude': -74.0036552270137},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '69 7th Ave S',
#    'address2': None,
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10014',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#   'phone': '+12129244466',
#   'display_phone': '(212) 924-4466',
#   'distance': 3469.471324042464},
#  {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#   'alias': 'artichoke-basilles-pizza-new-york-2',
#   'name': "Artichoke Basille's Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4krjwPml7pLVDnn56sf6AQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 4175,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7321124557704,
#    'longitude': -73.9839056828882},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '321 E 14th St',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '10003',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['321 E 14th St', 'New York, NY 10003']},
#   'phone': '+12122282004',
#   'display_phone': '(212) 228-2004',
#   'distance': 2823.0028388187757},
#  {'id': 'CiRj1B-gK5tRfbMkq3SBog',
#   'alias': 'robertas-new-york-3',
#   'name': "Roberta's",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/__bI5tzszdkyD9AdT_dfOw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/robertas-new-york-3?adjust_creative=EJHR_gL8G65r7e3w2olEqw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=EJHR_gL8G65r7e3w2olEqw',
#   'review_count': 4,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 40.71995520720623,
#    'longitude': -73.98304455197378},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '196 Stanton St',
#    'address2': '',
#    'address3': None,
#    'city': 'New York',
#    'zip_code': '10002',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['196 Stanton St', 'New York, NY 10002']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 1479.2037753077514}]

# %%
# Replace None with appropriate code

# Retrieve the value from response_json
businesses = response.json()["businesses"]

# View the first 2 records
businesses[2]["id"]
# Out:
# 'WG639VkTjmK5dzydd1BBJA'

# %% [markdown]
# ### Preparing Data
#
# Write a function `prepare_data` that takes in a list of dictionaries like `businesses` and returns a copy that has been prepared for analysis:
#
# 1. The `coordinates` key-value pair has been converted into two separate key-value pairs, `latitude` and `longitude`
# 2. All other key-value pairs except for `name`, `review_count`, `rating`, and `price` have been dropped
# 3. All dictionaries missing one of the relevant keys or containing null values have been dropped
#
# In other words, the final keys for each dictionary should be `name`, `review_count`, `rating`, `price`, `latitude`, and `longitude`.
#
# Complete the function in the cell below:

# %%
businesses[2]["coordinates"]["latitude"]
# Out:
# 40.722766

# %%
# Replace None with appropriate code

def prepare_data(data_list):
    """
    This function takes in a list of dictionaries and prepares it
    for analysis
    """
    
    # Make a new list to hold results
    results = []
    
    for b in data_list:
    
        # Make a new dictionary to hold prepared data for this business
        prepared_data = {}
        
        # Extract name, review_count, rating, and price key-value pairs
        # from business_data and add to prepared_data
        # If a key is not present in business_data, add it to prepared_data
        # with an associated value of None
        prepared_data["latitude"] = b["coordinates"]["latitude"]
        prepared_data["longitude"] = b["coordinates"]["longitude"]
                                                               
        for key in ("name", "review_count", "rating", "price"):
            prepared_data[key] = b.get(key, None)
    
        # Parse and add latitude and longitude columns
        None
        
        # Add to list if all values are present
        if all(prepared_data.values()):
            results.append(prepared_data)
    
    return results
    
# Test out function
prepared_businesses = prepare_data(businesses)
prepared_businesses[2]
# Out:
# {'latitude': 40.722766,
#  'longitude': -73.996233,
#  'name': 'Rubirosa',
#  'review_count': 2972,
#  'rating': 4.5,
#  'price': '$$'}

# %% [markdown]
# Check that your function created the correct keys:

# %%
# Run this cell without changes

assert sorted(list(prepared_businesses[0].keys())) == ['latitude', 'longitude', 'name', 'price', 'rating', 'review_count']

# %% [markdown]
# The following code will differ depending on your query, but we expect there to be 20 businesses in the original list, and potentially fewer in the prepared list (if any of them were missing data):

# %%
# Run this cell without changes
print("Original:", len(businesses))
print("Prepared:", len(prepared_businesses))
# Out:
# Original: 20
# Prepared: 19

# %% [markdown]
# Great! We will reuse this function once we have retrieved the full dataset.

# %% [markdown]
# ## 2. Add Pagination
#
# Now that you are able to extract information from one page of the response, let's figure out how to request as many pages as possible.
#
# ### Determining the Total
#
# Depending on the number of total results for your query, you will either retrieve all of the results, or just the first 1000 (if there are more than 1000 total).
#
# We can find the total number of results using the `"total"` key:

# %%
# Run this cell without changes
response_json["total"]
# Out:
# 16200

# %% [markdown]
# (This is specific to the implementation of the Yelp API. Some APIs will just tell you that there are more pages, or will tell you the number of pages total, rather than the total number of results. If you're not sure, always check the documentation.)
#
# In the cell below, assign the variable `total` to either the value shown above (if it is less than 1000), or 1000.

# %%
# Replace None with appropriate code
total = 1000

# %% [markdown]
# ### Calculating the Offsets
#
# The documentation states in the parameters section:
#
# > **Name**: `limit`, **Type:** int, **Description:** Optional. Number of business results to return. By default, it will return 20. Maximum is 50.
#
# > **Name**: `offset`, **Type:** int, **Description:** Optional. Offset the list of returned business results by this amount.
#
# So, to get the most results with the fewest API calls we want to set a limit of 50 every time. If, say, we wanted to get 210 total results, that would mean:
#
# 1. Offset of `0` (first 50 records)
# 2. Offset of `50` (second 50 records)
# 3. Offset of `100` (third 50 records)
# 4. Offset of `150` (fourth 50 records)
# 5. Offset of `200` (final 10 records)
#
# In the cell below, create a function `get_offsets` that takes in a total and returns a list of offsets for that total. You can assume that there is a limit of 50 every time.
#
# *Hint: you can use `range` ([documentation here](https://docs.python.org/3.3/library/stdtypes.html?highlight=range#range)) to do this in one line of code. Just make the returned result is a list.*

# %%
# Out:
# [0, 100, 200, 300, 400, 500, 600, 700, 800, 900]

# %%
# Replace None with appropriate code
def get_offsets(total):
    """
    Get a list of offsets needed to get all pages
    of data up until the total
    """
    return list(range(0,total,50))

# %% [markdown]
# Check that your function works below:

# %%
# Run this cell without changes

assert get_offsets(200) == [0, 50, 100, 150]
assert get_offsets(210) == [0, 50, 100, 150, 200]

# %% [markdown]
# ### Putting It All Together
#
# Recall that the following variable has already been declared for you:

# %%
# Run this cell without changes
url_params
# Out:
# {'term': 'Pizza', 'location': 'New+York+NY'}

# %% [markdown]
# We'll go ahead and also specify that the limit should be 50 every time:

# %%
# Run this cell without changes
url_params["limit"] = 50

# %% [markdown]
# In order to modify the offset, you'll need to add it to `url_params` with the key `"offset"` and whatever value is needed.
#
# In the cell below, write code that:
#
# * Creates an empty list for the full prepared dataset
# * Loops over all of the offsets from `get_offsets` and makes an API call each time with the specified offset
# * Calls `prepare_data` to get a cleaned version of the result of each API call
# * Extends the full prepared dataset list with each query's prepared dataset

# %%
# Replace None with appropriate code

# Create an empty list for the full prepared dataset
full_dataset = []

for offset in get_offsets(total):
    # Add or update the "offset" key-value pair in url_params
    url_params["offset"] = offset
    
    # Make the query and get the response
    response = requests.get(url, headers=headers, params=url_params)
    
    # Get the response body in JSON format
    response_json = response.json()
    
    # Get the list of businesses from the response_json
    businesses = response_json["businesses"]
    
    # Call the prepare_data function to get a list of processed data
    prepared_businesses = prepare_data(businesses)
    
    # Extend full_dataset with this list (don't append, or you'll get
    # a list of lists instead of a flat list)
    full_dataset.extend(prepared_businesses)

# Check the length of the full dataset. It will be up to `total`,
# potentially less if there were missing values
len(full_dataset)
# Out:
# 775

# %% [markdown]
# This code may take up to a few minutes to run.
#
# If you get an error trying to get the response body in JSON format, try adding `time.sleep(1)` right after the `requests.get` line, so your code will sleep for 1 second between each API call.

# %%
full_dataset
# Out:
# [{'latitude': 40.70274718768062,
#   'longitude': -73.99343490196397,
#   'name': "Juliana's",
#   'review_count': 2626,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.72308755605564,
#   'longitude': -73.99453001177575,
#   'name': 'Prince Street Pizza',
#   'review_count': 4840,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.722766,
#   'longitude': -73.996233,
#   'name': 'Rubirosa',
#   'review_count': 2972,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.71162,
#   'longitude': -73.95783,
#   'name': "L'industrie Pizzeria",
#   'review_count': 922,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7215934960083,
#   'longitude': -73.9955956044561,
#   'name': "Lombardi's Pizza",
#   'review_count': 6558,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73060076,
#   'longitude': -74.00215997,
#   'name': "Joe's Pizza",
#   'review_count': 2995,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7547,
#   'longitude': -73.98696,
#   'name': "Joe's Pizza",
#   'review_count': 1855,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.73158,
#   'longitude': -74.00332,
#   'name': "John's of Bleecker Street",
#   'review_count': 2535,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7026459,
#   'longitude': -73.9932413,
#   'name': "Grimaldi's Pizzeria",
#   'review_count': 4919,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.71534,
#   'longitude': -73.9914,
#   'name': "Scarr's Pizza",
#   'review_count': 739,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.733798036104304,
#   'longitude': -73.99977392649927,
#   'name': 'Olio e Più',
#   'review_count': 4251,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.69116658201196,
#   'longitude': -73.99065911521895,
#   'name': 'Piz-zetta',
#   'review_count': 338,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.681840746711224,
#   'longitude': -74.0003327,
#   'name': 'Lucali',
#   'review_count': 1950,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7168952,
#   'longitude': -73.95892996733771,
#   'name': "Joe's Pizza",
#   'review_count': 438,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.71958,
#   'longitude': -73.99734,
#   'name': 'Gelso & Grand',
#   'review_count': 1388,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.6897,
#   'longitude': -73.965369,
#   'name': "Luigi's Pizzeria",
#   'review_count': 283,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7101297729083,
#   'longitude': -74.0077206864953,
#   'name': "Joe's Pizza",
#   'review_count': 448,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7320627016512,
#   'longitude': -74.0036552270137,
#   'name': 'Bleecker Street Pizza',
#   'review_count': 2809,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7208883,
#   'longitude': -73.9962404,
#   'name': 'Nolita Pizza',
#   'review_count': 197,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.70493,
#   'longitude': -73.93399,
#   'name': "Roberta's",
#   'review_count': 3258,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.729546,
#   'longitude': -73.958568,
#   'name': "Paulie Gee's",
#   'review_count': 1340,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.723625,
#   'longitude': -73.988555,
#   'name': "Lil Frankie's",
#   'review_count': 1434,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.70244,
#   'longitude': -73.98943,
#   'name': 'Front Street Pizza',
#   'review_count': 448,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7502059936523,
#   'longitude': -73.9953231811523,
#   'name': 'NY Pizza Suprema',
#   'review_count': 2443,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7826,
#   'longitude': -73.95351,
#   'name': 'Marinara Pizza',
#   'review_count': 328,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.75225,
#   'longitude': -73.98061,
#   'name': 'Stone Bridge Pizza & Salad',
#   'review_count': 321,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.72748,
#   'longitude': -73.98268,
#   'name': 'Village Square Pizza',
#   'review_count': 269,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.743553,
#   'longitude': -73.980026,
#   'name': 'Norma',
#   'review_count': 603,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.72813,
#   'longitude': -74.00188,
#   'name': 'Song E Napule',
#   'review_count': 685,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.76458,
#   'longitude': -73.98247,
#   'name': '99 Cent Fresh Pizza',
#   'review_count': 684,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.710372,
#   'longitude': -73.96794,
#   'name': 'Barano',
#   'review_count': 315,
#   'rating': 4.5,
#   'price': '$$$'},
#  {'latitude': 40.6950309,
#   'longitude': -73.9961252,
#   'name': "Dellarocco's Brick Oven Pizza",
#   'review_count': 348,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.594715,
#   'longitude': -73.981316,
#   'name': 'L & B Spumoni Gardens',
#   'review_count': 4550,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.70424819999999,
#   'longitude': -74.0101127,
#   'name': "Adrienne's Pizzabar",
#   'review_count': 1829,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.71505,
#   'longitude': -73.958365,
#   'name': "Ace's Pizza",
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.73398,
#   'longitude': -73.98961,
#   'name': 'Unregular Pizza',
#   'review_count': 200,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7321124557704,
#   'longitude': -73.9839056828882,
#   'name': "Artichoke Basille's Pizza",
#   'review_count': 4175,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6974427,
#   'longitude': -73.9675197,
#   'name': 'Il Porto',
#   'review_count': 383,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.75334,
#   'longitude': -73.93716,
#   'name': 'Goodfellas Pizzeria of LIC',
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.72836,
#   'longitude': -73.9572,
#   'name': "Paulie Gee's Slice Shop",
#   'review_count': 322,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.728212,
#   'longitude': -73.985182,
#   'name': 'East Village Pizza',
#   'review_count': 488,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7608512,
#   'longitude': -73.9694809,
#   'name': 'My Pie Pizzeria Romana',
#   'review_count': 896,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.783841,
#   'longitude': -73.977569,
#   'name': 'Made In New York Pizza',
#   'review_count': 508,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.844287,
#   'longitude': -73.939259,
#   'name': 'Koronet Pizza',
#   'review_count': 120,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6854737,
#   'longitude': -73.9203186,
#   'name': 'Cuts & Slices',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7215270996094,
#   'longitude': -73.9970855712891,
#   'name': 'Champion Pizza',
#   'review_count': 419,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.797157,
#   'longitude': -73.93488,
#   'name': "Patsy's Pizzeria",
#   'review_count': 932,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.75674,
#   'longitude': -73.96431,
#   'name': 'Sofia Pizza Shoppe',
#   'review_count': 244,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7177776,
#   'longitude': -74.0442612,
#   'name': 'Razza',
#   'review_count': 1188,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.680702,
#   'longitude': -73.967455,
#   'name': "Brooklyn's Homeslice Pizzeria",
#   'review_count': 190,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7084890714263,
#   'longitude': -73.9610940711639,
#   'name': 'Roebling Pizza',
#   'review_count': 135,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.62207,
#   'longitude': -74.02591,
#   'name': "Mancini's Wood-Fired Pizza",
#   'review_count': 146,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.6998,
#   'longitude': -73.92842,
#   'name': 'Rosie Pizza Bar',
#   'review_count': 45,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7189,
#   'longitude': -73.956843,
#   'name': "Vinnie's Pizzeria",
#   'review_count': 747,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7302,
#   'longitude': -73.98069,
#   'name': 'Burrata Pizza',
#   'review_count': 29,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7591676767848,
#   'longitude': -73.9525466887989,
#   'name': 'Piccolo Trattoria',
#   'review_count': 118,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.71822,
#   'longitude': -73.99123,
#   'name': 'Williamsburg Pizza',
#   'review_count': 276,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.725612,
#   'longitude': -74.007916,
#   'name': 'Adoro Lei',
#   'review_count': 357,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7334346,
#   'longitude': -73.9916923,
#   'name': 'Ribalta Pizza',
#   'review_count': 752,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.92033366683442,
#   'longitude': -73.86751644723435,
#   'name': 'Pizza Barn',
#   'review_count': 503,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.703137,
#   'longitude': -73.993608,
#   'name': "Ignazio's",
#   'review_count': 618,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.6904563903809,
#   'longitude': -73.9696273803711,
#   'name': "Graziella's",
#   'review_count': 493,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.692930215177675,
#   'longitude': -74.00165153160219,
#   'name': 'Fornino',
#   'review_count': 293,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8280452239988,
#   'longitude': -73.9489363226845,
#   'name': 'Jumbo Pizza Coffee Shop',
#   'review_count': 91,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.707492,
#   'longitude': -74.002571,
#   'name': 'IL Brigante',
#   'review_count': 493,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7392597584612,
#   'longitude': -74.0088130692187,
#   'name': 'SIMÒ PIZZA',
#   'review_count': 240,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.62236,
#   'longitude': -74.0055,
#   'name': 'Krispy Pizza ',
#   'review_count': 335,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.67206,
#   'longitude': -73.95717,
#   'name': 'Barboncino Pizza & Bar',
#   'review_count': 1119,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.688285,
#   'longitude': -73.989006,
#   'name': 'Sottocasa Pizzeria',
#   'review_count': 708,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7634285660493,
#   'longitude': -73.81413158435902,
#   'name': 'Mahsil',
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.70342863348067,
#   'longitude': -73.99214637055226,
#   'name': 'Time Out Market New York',
#   'review_count': 469,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.66163,
#   'longitude': -73.99334,
#   'name': "Luigi's Pizza",
#   'review_count': 473,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.9647045,
#   'longitude': -73.8391204,
#   'name': 'Frank Pepe Pizzeria Napoletana',
#   'review_count': 751,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.714987,
#   'longitude': -73.94414,
#   'name': "Carmine's Pizzeria",
#   'review_count': 520,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.76492,
#   'longitude': -73.97794,
#   'name': "Angelo's Coal Oven Pizzeria",
#   'review_count': 1145,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6914284,
#   'longitude': -73.9824964,
#   'name': "Antonio's Pizzeria & Restaurant",
#   'review_count': 267,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.76032,
#   'longitude': -73.82813,
#   'name': 'Lucia Pizza',
#   'review_count': 641,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.725290886426,
#   'longitude': -73.946226015687,
#   'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.74764,
#   'longitude': -73.94173,
#   'name': 'Levante',
#   'review_count': 331,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.714987,
#   'longitude': -73.94414,
#   'name': "Carmine's Pizzeria",
#   'review_count': 520,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6914284,
#   'longitude': -73.9824964,
#   'name': "Antonio's Pizzeria & Restaurant",
#   'review_count': 267,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.76032,
#   'longitude': -73.82813,
#   'name': 'Lucia Pizza',
#   'review_count': 641,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.725290886426,
#   'longitude': -73.946226015687,
#   'name': "Tony's Pizzeria of Nassau Ave",
#   'review_count': 63,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.74764,
#   'longitude': -73.94173,
#   'name': 'Levante',
#   'review_count': 331,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6882597,
#   'longitude': -73.9626018,
#   'name': 'The 3 Luigis',
#   'review_count': 97,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.779999,
#   'longitude': -73.980301,
#   'name': "Freddie & Pepper's",
#   'review_count': 519,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7156,
#   'longitude': -73.95352,
#   'name': 'Best Pizza',
#   'review_count': 707,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.6985,
#   'longitude': -73.99273,
#   'name': 'Fascati Pizza',
#   'review_count': 264,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.713245675315,
#   'longitude': -73.998651104496,
#   'name': 'Luna Pizza',
#   'review_count': 100,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73039,
#   'longitude': -73.98381,
#   'name': 'Motorino',
#   'review_count': 1122,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.74506,
#   'longitude': -73.99834,
#   'name': 'Lions & Tigers & Squares Detroit Pizza',
#   'review_count': 541,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6743319055498,
#   'longitude': -73.9816949398812,
#   'name': 'La Villa',
#   'review_count': 587,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.821427,
#   'longitude': -73.950638,
#   'name': 'Fumo - Harlem',
#   'review_count': 564,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.712121,
#   'longitude': -74.009704,
#   'name': 'Stage Door Pizzeria',
#   'review_count': 290,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.719742,
#   'longitude': -73.9872791,
#   'name': 'Champion Pizza',
#   'review_count': 162,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7445882,
#   'longitude': -73.9847936,
#   'name': 'Marta',
#   'review_count': 1009,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.71338,
#   'longitude': -73.95136,
#   'name': 'Montesacro Pinseria Brooklyn',
#   'review_count': 236,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.691219329834,
#   'longitude': -73.9973449707031,
#   'name': 'Table 87 - Brooklyn Heights',
#   'review_count': 345,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.721836749997586,
#   'longitude': -73.98329136062472,
#   'name': 'Luzzos La Pizza Napoletana',
#   'review_count': 1090,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72981093692917,
#   'longitude': -73.9926904,
#   'name': '&pizza - Astor Place',
#   'review_count': 217,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.72892,
#   'longitude': -73.98411,
#   'name': "Joe & Pat's Pizzeria",
#   'review_count': 295,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6627403949909,
#   'longitude': -73.8403776268684,
#   'name': 'New Park Pizza',
#   'review_count': 1032,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6349400235262,
#   'longitude': -73.9625812061059,
#   'name': 'Lo Duca Pizza',
#   'review_count': 151,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.6302266718896,
#   'longitude': -74.1402754933448,
#   'name': "Denino's Pizzeria & Tavern",
#   'review_count': 922,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7139499,
#   'longitude': -73.95563,
#   'name': "Rosa's Pizza",
#   'review_count': 190,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.699286,
#   'longitude': -73.918724,
#   'name': "Tony's Pizzeria & Restaurant",
#   'review_count': 359,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.718554,
#   'longitude': -73.997447,
#   'name': 'Paesano of Mulberry Street',
#   'review_count': 1363,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6199507795829,
#   'longitude': -73.9896828,
#   'name': 'J & V Pizzeria',
#   'review_count': 272,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7143,
#   'longitude': -73.98172,
#   'name': "Alphonso's Pizzeria & Trattoria",
#   'review_count': 153,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.73069,
#   'longitude': -74.00015,
#   'name': 'La Lanterna Di Vittorio',
#   'review_count': 1639,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7089474315161,
#   'longitude': -73.83051320334309,
#   'name': "Dani's House of Pizza",
#   'review_count': 1172,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.722121,
#   'longitude': -73.956678,
#   'name': 'Leuca',
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.712168,
#   'longitude': -73.955707,
#   'name': 'Emmy Squared Pizza - Williamsburg',
#   'review_count': 776,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.750244140625,
#   'longitude': -73.9970245361328,
#   'name': "Scott's Pizza Tours",
#   'review_count': 367,
#   'rating': 5.0,
#   'price': '$$'},
#  {'latitude': 40.6810107667113,
#   'longitude': -73.9771813899279,
#   'name': "Artichoke Basille's Pizza",
#   'review_count': 435,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.762711,
#   'longitude': -73.986708,
#   'name': 'Don Antonio',
#   'review_count': 1640,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.728949,
#   'longitude': -73.953999,
#   'name': 'Fornino- Greenpoint',
#   'review_count': 248,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8029069,
#   'longitude': -73.9510825,
#   'name': 'Harlem Pizza Co',
#   'review_count': 221,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.76388,
#   'longitude': -73.98821,
#   'name': 'B Side Pizza & Wine Bar',
#   'review_count': 1282,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.70276,
#   'longitude': -73.9171,
#   'name': 'Ops',
#   'review_count': 186,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.756482,
#   'longitude': -73.981484,
#   'name': 'Little Italy Pizza',
#   'review_count': 599,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6875154792236,
#   'longitude': -73.959874469611,
#   'name': 'Speedy Romeo',
#   'review_count': 675,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72043,
#   'longitude': -73.98894,
#   'name': 'Trapizzino',
#   'review_count': 294,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.596872,
#   'longitude': -73.976309,
#   'name': "Ciccio's Pizza",
#   'review_count': 128,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.75214,
#   'longitude': -73.934339,
#   'name': "Mike's Pizza",
#   'review_count': 148,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.73068,
#   'longitude': -74.00042,
#   'name': 'Artistic Pizza',
#   'review_count': 117,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.6375122070312,
#   'longitude': -73.9994735717773,
#   'name': 'Jentana Pizza Restaurant',
#   'review_count': 76,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7189865112305,
#   'longitude': -73.9969329833984,
#   'name': 'Margherita NYC',
#   'review_count': 315,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.711942,
#   'longitude': -73.999349,
#   'name': 'Famous Calabria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7081041823001,
#   'longitude': -74.0046897976739,
#   'name': 'Little Italy Pizza',
#   'review_count': 169,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.79508,
#   'longitude': -74.06316,
#   'name': "Natoli's",
#   'review_count': 329,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.842018,
#   'longitude': -74.000809,
#   'name': 'K Pizza',
#   'review_count': 68,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.76564,
#   'longitude': -73.9830099,
#   'name': 'Joe G Pizza & Restaurant',
#   'review_count': 170,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.670664,
#   'longitude': -73.991371,
#   'name': 'Table 87 - Gowanus',
#   'review_count': 419,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.727303,
#   'longitude': -74.00243,
#   'name': "Emmett's",
#   'review_count': 593,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.78272735790179,
#   'longitude': -73.9478073,
#   'name': "Nick's Pizza",
#   'review_count': 586,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.755403,
#   'longitude': -73.994516,
#   'name': 'Tavola',
#   'review_count': 1261,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7412157,
#   'longitude': -73.9938935,
#   'name': "Grimaldi's",
#   'review_count': 832,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.78329,
#   'longitude': -73.978,
#   'name': "Saba's Pizza",
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.767086,
#   'longitude': -73.983033,
#   'name': "Pop's Pizzas",
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.735097,
#   'longitude': -73.979074,
#   'name': 'Rosemary’s',
#   'review_count': 214,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.76337,
#   'longitude': -73.915124,
#   'name': "Rizzo's Fine Pizza",
#   'review_count': 656,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824,
#   'name': "Ray's Pizza",
#   'review_count': 415,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.7139015197754,
#   'longitude': -73.96044921875,
#   'name': 'Baci & Abbracci',
#   'review_count': 347,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6837407,
#   'longitude': -73.9353473,
#   'name': 'Saraghina Pizzeria',
#   'review_count': 1008,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73829,
#   'longitude': -74.0054,
#   'name': 'Brunetti Pizza',
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596,
#   'name': 'PizzArte',
#   'review_count': 1264,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72981,
#   'longitude': -73.98658,
#   'name': 'Marinara Pizza',
#   'review_count': 31,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.73483,
#   'longitude': -73.98282,
#   'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7057647,
#   'longitude': -74.0085474,
#   'name': '&pizza - Wall St',
#   'review_count': 143,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.670664,
#   'longitude': -73.991371,
#   'name': 'Table 87 - Gowanus',
#   'review_count': 419,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.727303,
#   'longitude': -74.00243,
#   'name': "Emmett's",
#   'review_count': 593,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.78272735790179,
#   'longitude': -73.9478073,
#   'name': "Nick's Pizza",
#   'review_count': 586,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.755403,
#   'longitude': -73.994516,
#   'name': 'Tavola',
#   'review_count': 1261,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7412157,
#   'longitude': -73.9938935,
#   'name': "Grimaldi's",
#   'review_count': 832,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.78329,
#   'longitude': -73.978,
#   'name': "Saba's Pizza",
#   'review_count': 120,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.767086,
#   'longitude': -73.983033,
#   'name': "Pop's Pizzas",
#   'review_count': 142,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.735097,
#   'longitude': -73.979074,
#   'name': 'Rosemary’s',
#   'review_count': 214,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.76337,
#   'longitude': -73.915124,
#   'name': "Rizzo's Fine Pizza",
#   'review_count': 656,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7604321973079,
#   'longitude': -73.9839891042824,
#   'name': "Ray's Pizza",
#   'review_count': 415,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.7139015197754,
#   'longitude': -73.96044921875,
#   'name': 'Baci & Abbracci',
#   'review_count': 347,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6837407,
#   'longitude': -73.9353473,
#   'name': 'Saraghina Pizzeria',
#   'review_count': 1008,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73829,
#   'longitude': -74.0054,
#   'name': 'Brunetti Pizza',
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7629335072372,
#   'longitude': -73.9776668697596,
#   'name': 'PizzArte',
#   'review_count': 1264,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.789283,
#   'longitude': -73.9487429,
#   'name': 'Lexington Pizza Parlour',
#   'review_count': 256,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72981,
#   'longitude': -73.98658,
#   'name': 'Marinara Pizza',
#   'review_count': 31,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.73483,
#   'longitude': -73.98282,
#   'name': 'POSTO NYCThinCrust Pizza',
#   'review_count': 659,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7057647,
#   'longitude': -74.0085474,
#   'name': '&pizza - Wall St',
#   'review_count': 143,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.6933151509676,
#   'longitude': -73.9290830120444,
#   'name': 'Broadway Pizzeria',
#   'review_count': 129,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.773986,
#   'longitude': -73.908126,
#   'name': 'Tufino Pizzeria Napoletana',
#   'review_count': 456,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.669342,
#   'longitude': -73.896667,
#   'name': 'Carranza Pizza',
#   'review_count': 9,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.73314309005766,
#   'longitude': -74.0027964258894,
#   'name': 'Two Boots Pizza - West Village',
#   'review_count': 62,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7509380299598,
#   'longitude': -73.9767879766344,
#   'name': 'Previti Pizza',
#   'review_count': 447,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.70499,
#   'longitude': -74.00961,
#   'name': 'Underground Pizza',
#   'review_count': 333,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7190165,
#   'longitude': -73.9586248,
#   'name': 'Oregano',
#   'review_count': 496,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.759494511551836,
#   'longitude': -73.98673451962638,
#   'name': 'Patzeria Perfect Pizza',
#   'review_count': 1793,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7349243164062,
#   'longitude': -73.9855880737305,
#   'name': 'Follia',
#   'review_count': 279,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.7204716,
#   'longitude': -73.9893263,
#   'name': 'Sauce',
#   'review_count': 920,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.744435447210506,
#   'longitude': -73.9814189,
#   'name': 'VEZZO NYCThinCrust Pizza',
#   'review_count': 1387,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.70638449968762,
#   'longitude': -73.92288771165168,
#   'name': "Artichoke Basille's Pizza",
#   'review_count': 299,
#   'rating': 3.0,
#   'price': '$$'},
#  {'latitude': 40.693154,
#   'longitude': -73.967177,
#   'name': 'Osteria Brooklyn',
#   'review_count': 191,
#   'rating': 4.5,
#   'price': '$$$'},
#  {'latitude': 40.69224,
#   'longitude': -73.945849,
#   'name': 'Rocco Pizza',
#   'review_count': 207,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.73293764919451,
#   'longitude': -73.99758608256435,
#   'name': 'Loring Place',
#   'review_count': 533,
#   'rating': 4.5,
#   'price': '$$$'},
#  {'latitude': 40.71087,
#   'longitude': -73.95069,
#   'name': 'Singas Famous Pizza',
#   'review_count': 103,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.70937768719562,
#   'longitude': -74.00483341921786,
#   'name': 'Kesté Pizza & Vino',
#   'review_count': 1567,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6905570310882,
#   'longitude': -73.99494681265617,
#   'name': 'BRADO NYCThinCrust Pizza',
#   'review_count': 163,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.77843,
#   'longitude': -73.94863,
#   'name': 'Roma Pizza',
#   'review_count': 381,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7033063330116,
#   'longitude': -73.9916549604523,
#   'name': "Cecconi's Dumbo",
#   'review_count': 1024,
#   'rating': 3.5,
#   'price': '$$$'},
#  {'latitude': 40.69165,
#   'longitude': -73.98603,
#   'name': 'Circa Brewing',
#   'review_count': 408,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8875232,
#   'longitude': -73.90704,
#   'name': 'Salvatores of Soho',
#   'review_count': 334,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7219179851303,
#   'longitude': -73.9976472073402,
#   'name': 'Osteria Morini',
#   'review_count': 1281,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.77479,
#   'longitude': -73.91186,
#   'name': "Rosario's",
#   'review_count': 190,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.8055499,
#   'longitude': -73.94746,
#   'name': 'Sottocasa Pizzeria - Harlem',
#   'review_count': 332,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.63781,
#   'longitude': -73.8963799,
#   'name': 'Original Pizza',
#   'review_count': 136,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.715948062187,
#   'longitude': -73.9873785183775,
#   'name': "Saluggi's East",
#   'review_count': 134,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.723658440431656,
#   'longitude': -73.98503439649534,
#   'name': 'Two Boots East Village',
#   'review_count': 413,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.683944,
#   'longitude': -74.00225,
#   'name': 'House of Pizza & Calzones',
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.68598633824293,
#   'longitude': -73.9740807999429,
#   'name': "Not Ray's Pizza",
#   'review_count': 250,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.80638,
#   'longitude': -73.95371,
#   'name': 'Rosa Pizzeria of Harlem',
#   'review_count': 20,
#   'rating': 5.0,
#   'price': '$'},
#  {'latitude': 40.6742098,
#   'longitude': -73.9824143,
#   'name': 'Two Boots Park Slope',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.73596,
#   'longitude': -74.00093,
#   'name': "Roey's",
#   'review_count': 178,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6603430973463,
#   'longitude': -73.9907741546631,
#   'name': "Giuseppina's",
#   'review_count': 348,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7045845329735,
#   'longitude': -73.7967360578922,
#   'name': 'Margherita Pizza',
#   'review_count': 358,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7372,
#   'longitude': -73.99919,
#   'name': 'Sotto 13',
#   'review_count': 1040,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.61692,
#   'longitude': -73.9098,
#   'name': 'La Villa Pizzeria & Restaurant',
#   'review_count': 326,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.75823,
#   'longitude': -73.98836,
#   'name': "John's of Times Square",
#   'review_count': 2415,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.715621,
#   'longitude': -73.964757,
#   'name': 'Aurora',
#   'review_count': 802,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7569046125342,
#   'longitude': -73.980516,
#   'name': "Nino's 46",
#   'review_count': 1371,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7073067,
#   'longitude': -73.922154,
#   'name': 'Union Pizza Works',
#   'review_count': 291,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73778,
#   'longitude': -74.00197,
#   'name': 'Don Angie',
#   'review_count': 687,
#   'rating': 4.5,
#   'price': '$$$'},
#  {'latitude': 40.71832,
#   'longitude': -73.99794,
#   'name': 'Da Gennaro',
#   'review_count': 1259,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.7238165289164,
#   'longitude': -73.9504531770945,
#   'name': 'Prince Pizza',
#   'review_count': 48,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.713375,
#   'longitude': -74.035044,
#   'name': 'Krispy Pizza',
#   'review_count': 244,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.729375015649076,
#   'longitude': -74.00386306706551,
#   'name': 'Emily - West Village',
#   'review_count': 938,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8028109023738,
#   'longitude': -73.9641991912535,
#   'name': 'Marlow Bistro',
#   'review_count': 350,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.685920715332,
#   'longitude': -73.9945220947266,
#   'name': "Sam's",
#   'review_count': 237,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.690706,
#   'longitude': -73.9952269,
#   'name': "Luzzo's BK",
#   'review_count': 213,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.706518,
#   'longitude': -74.007505,
#   'name': 'Artichoke Basille’s Pizza',
#   'review_count': 76,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.727966,
#   'longitude': -73.988382,
#   'name': 'San Marzano Pasta Fresca',
#   'review_count': 1513,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.70933,
#   'longitude': -73.95407,
#   'name': 'Dough Vale',
#   'review_count': 105,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.704239,
#   'longitude': -73.9072084,
#   'name': "Julie's Pizzeria & Restaurant",
#   'review_count': 63,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.754057,
#   'longitude': -73.989497,
#   'name': "Lazzara's Pizza",
#   'review_count': 344,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.80334,
#   'longitude': -73.96383,
#   'name': 'V & T Pizzeria & Restaurant',
#   'review_count': 389,
#   'rating': 3.0,
#   'price': '$$'},
#  {'latitude': 40.74337,
#   'longitude': -73.99153,
#   'name': 'TAPPO NYCThinCrust Pizza',
#   'review_count': 567,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.85536,
#   'longitude': -73.88758,
#   'name': 'Full Moon Pizzeria',
#   'review_count': 342,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7664835,
#   'longitude': -73.9633564,
#   'name': 'Oath Pizza - New York',
#   'review_count': 261,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6788288,
#   'longitude': -74.0113214,
#   'name': "Mark's Red Hook Pizza",
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.729076,
#   'longitude': -74.001534,
#   'name': "Percy's Pizza",
#   'review_count': 255,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.788956,
#   'longitude': -73.814049,
#   'name': "Freddy's Pizzeria",
#   'review_count': 105,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7402335928167,
#   'longitude': -73.9238661770474,
#   'name': 'Marabella Pizza',
#   'review_count': 146,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.707999,
#   'longitude': -74.0142651,
#   'name': 'Sauce & Barrel',
#   'review_count': 572,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7378974,
#   'longitude': -74.0343764,
#   'name': "Tony Boloney's - Hoboken",
#   'review_count': 672,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.7196979,
#   'longitude': -73.9951175,
#   'name': 'Piacere',
#   'review_count': 713,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7249388,
#   'longitude': -74.002451,
#   'name': "Famous Ben's Pizza",
#   'review_count': 391,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.73357,
#   'longitude': -73.955116,
#   'name': 'Triangolo Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.67751,
#   'longitude': -73.82586,
#   'name': "Sofia's Pizza",
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.75681,
#   'longitude': -73.980238,
#   'name': '2 Bros Pizza',
#   'review_count': 452,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.77505,
#   'longitude': -73.98088,
#   'name': 'LA Traviata Pizzeria',
#   'review_count': 202,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.77528,
#   'longitude': -73.94737,
#   'name': "Arturo's Pizza",
#   'review_count': 162,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.72697,
#   'longitude': -73.89564,
#   'name': "Rosa's Pizza",
#   'review_count': 449,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.768596558477746,
#   'longitude': -73.90993694976152,
#   'name': 'Nonnas 1977',
#   'review_count': 175,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7658680230835,
#   'longitude': -73.9576601066113,
#   'name': "Patsy's Pizzeria",
#   'review_count': 339,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.754827,
#   'longitude': -73.935918,
#   'name': "Beebe's",
#   'review_count': 168,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.706858,
#   'longitude': -73.855654,
#   'name': 'Pizza Classica',
#   'review_count': 486,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.67741,
#   'longitude': -73.98265,
#   'name': 'Public Display of Affection',
#   'review_count': 72,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.68903,
#   'longitude': -73.92408,
#   'name': 'Bklyn Pizza',
#   'review_count': 172,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7235518,
#   'longitude': -73.95065,
#   'name': "Screamer's Pizzeria",
#   'review_count': 433,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.79392,
#   'longitude': -73.93427,
#   'name': "Rao's",
#   'review_count': 209,
#   'rating': 4.5,
#   'price': '$$$$'},
#  {'latitude': 40.728,
#   'longitude': -74.0001497,
#   'name': 'Carbone',
#   'review_count': 1590,
#   'rating': 4.0,
#   'price': '$$$$'},
#  {'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708,
#   'name': 'Love & Dough',
#   'review_count': 251,
#   'rating': 3.0,
#   'price': '$$'},
#  {'latitude': 40.655633751718426,
#   'longitude': -73.9503288,
#   'name': 'The Swiss Slice',
#   'review_count': 33,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.783433,
#   'longitude': -73.947932,
#   'name': 'Enzo Bruni La Pizza Gourmet',
#   'review_count': 108,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7632745057344,
#   'longitude': -73.9815969765186,
#   'name': "Famous Original Ray's Pizza",
#   'review_count': 434,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.917609,
#   'longitude': -73.839425,
#   'name': "Johnny's Pizzeria",
#   'review_count': 411,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.750427,
#   'longitude': -73.972129,
#   'name': "Patsy's Pizzeria",
#   'review_count': 316,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.7442813,
#   'longitude': -74.0503861,
#   'name': "Renato's Pizza Masters",
#   'review_count': 469,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.76348,
#   'longitude': -73.978091,
#   'name': 'Pazza Notte',
#   'review_count': 1015,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.62129,
#   'longitude': -74.02659,
#   'name': 'Pizza Wagon',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.873216463621,
#   'longitude': -73.8888399776716,
#   'name': 'Jerome Pizza',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.72866,
#   'longitude': -73.988487,
#   'name': '2 Bros Pizza',
#   'review_count': 629,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.76652,
#   'longitude': -73.9598,
#   'name': 'Donna Margherita',
#   'review_count': 170,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.667031,
#   'longitude': -73.981287,
#   'name': 'Smiling Pizza Restaurant',
#   'review_count': 266,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283,
#   'name': "Artichoke Basille's Pizza",
#   'review_count': 1692,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026,
#   'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4477,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7249388,
#   'longitude': -74.002451,
#   'name': "Famous Ben's Pizza",
#   'review_count': 391,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.73357,
#   'longitude': -73.955116,
#   'name': 'Triangolo Pizza',
#   'review_count': 135,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.67751,
#   'longitude': -73.82586,
#   'name': "Sofia's Pizza",
#   'review_count': 271,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.62849,
#   'longitude': -74.02917,
#   'name': "Luliano's",
#   'review_count': 88,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.75681,
#   'longitude': -73.980238,
#   'name': '2 Bros Pizza',
#   'review_count': 452,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.77505,
#   'longitude': -73.98088,
#   'name': 'LA Traviata Pizzeria',
#   'review_count': 202,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.77528,
#   'longitude': -73.94737,
#   'name': "Arturo's Pizza",
#   'review_count': 162,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.72697,
#   'longitude': -73.89564,
#   'name': "Rosa's Pizza",
#   'review_count': 449,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.768596558477746,
#   'longitude': -73.90993694976152,
#   'name': 'Nonnas 1977',
#   'review_count': 175,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7658680230835,
#   'longitude': -73.9576601066113,
#   'name': "Patsy's Pizzeria",
#   'review_count': 339,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.754827,
#   'longitude': -73.935918,
#   'name': "Beebe's",
#   'review_count': 168,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.706858,
#   'longitude': -73.855654,
#   'name': 'Pizza Classica',
#   'review_count': 486,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6842863,
#   'longitude': -73.8594333,
#   'name': "Enzo's Pizzeria",
#   'review_count': 111,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.67741,
#   'longitude': -73.98265,
#   'name': 'Public Display of Affection',
#   'review_count': 72,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.68903,
#   'longitude': -73.92408,
#   'name': 'Bklyn Pizza',
#   'review_count': 172,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7235518,
#   'longitude': -73.95065,
#   'name': "Screamer's Pizzeria",
#   'review_count': 433,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.79392,
#   'longitude': -73.93427,
#   'name': "Rao's",
#   'review_count': 209,
#   'rating': 4.5,
#   'price': '$$$$'},
#  {'latitude': 40.728,
#   'longitude': -74.0001497,
#   'name': 'Carbone',
#   'review_count': 1590,
#   'rating': 4.0,
#   'price': '$$$$'},
#  {'latitude': 40.702950557308085,
#   'longitude': -73.98748593042708,
#   'name': 'Love & Dough',
#   'review_count': 251,
#   'rating': 3.0,
#   'price': '$$'},
#  {'latitude': 40.655633751718426,
#   'longitude': -73.9503288,
#   'name': 'The Swiss Slice',
#   'review_count': 33,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.783433,
#   'longitude': -73.947932,
#   'name': 'Enzo Bruni La Pizza Gourmet',
#   'review_count': 108,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7632745057344,
#   'longitude': -73.9815969765186,
#   'name': "Famous Original Ray's Pizza",
#   'review_count': 434,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.63465,
#   'longitude': -74.0233,
#   'name': 'Original Pizza',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.917609,
#   'longitude': -73.839425,
#   'name': "Johnny's Pizzeria",
#   'review_count': 411,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.750427,
#   'longitude': -73.972129,
#   'name': "Patsy's Pizzeria",
#   'review_count': 316,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.7442813,
#   'longitude': -74.0503861,
#   'name': "Renato's Pizza Masters",
#   'review_count': 469,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.76348,
#   'longitude': -73.978091,
#   'name': 'Pazza Notte',
#   'review_count': 1015,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.62129,
#   'longitude': -74.02659,
#   'name': 'Pizza Wagon',
#   'review_count': 309,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.873216463621,
#   'longitude': -73.8888399776716,
#   'name': 'Jerome Pizza',
#   'review_count': 82,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.72866,
#   'longitude': -73.988487,
#   'name': '2 Bros Pizza',
#   'review_count': 629,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.76652,
#   'longitude': -73.9598,
#   'name': 'Donna Margherita',
#   'review_count': 170,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.72474,
#   'longitude': -73.98161,
#   'name': 'GRUPPO NYCThinCrust Pizza',
#   'review_count': 275,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.667031,
#   'longitude': -73.981287,
#   'name': 'Smiling Pizza Restaurant',
#   'review_count': 266,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.74406421842744,
#   'longitude': -74.00655890429283,
#   'name': "Artichoke Basille's Pizza",
#   'review_count': 1692,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.75749848725768,
#   'longitude': -73.98665333142026,
#   'name': "Carmine's Italian Restaurant - Times Square",
#   'review_count': 4477,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.73612,
#   'longitude': -73.979473,
#   'name': "Frank's Trattoria",
#   'review_count': 175,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.675178,
#   'longitude': -73.96308,
#   'name': "Gino's Cucina & Brick Oven Pizza",
#   'review_count': 67,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.867915,
#   'longitude': -73.900536,
#   'name': "Emilio's Pizza",
#   'review_count': 28,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.71959,
#   'longitude': -73.8426,
#   'name': 'Austin Street Pizza',
#   'review_count': 197,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.8417046944816,
#   'longitude': -73.7070563506088,
#   'name': "Salvatore's Coal Oven Pizzeria",
#   'review_count': 273,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.70214,
#   'longitude': -73.8807999,
#   'name': 'Grace Pizza',
#   'review_count': 118,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7039355145338,
#   'longitude': -74.0121731758117,
#   'name': 'Antica Ristorante',
#   'review_count': 552,
#   'rating': 4.5,
#   'price': '$$$'},
#  {'latitude': 40.634741,
#   'longitude': -74.0284259,
#   'name': "Lombardo's of Bay Ridge",
#   'review_count': 195,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.6112945152771,
#   'longitude': -74.0082534402609,
#   'name': 'La Villa Pizzeria',
#   'review_count': 156,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8898885,
#   'longitude': -74.0248396,
#   'name': "Victor's Pizzeria & Italian Restaurant",
#   'review_count': 195,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.6941108703613,
#   'longitude': -73.8500289916992,
#   'name': "Joe's Pasta & Pizza Restaurant",
#   'review_count': 15,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.90183233855396,
#   'longitude': -73.79090498984223,
#   'name': 'Pizzeria La Rosa',
#   'review_count': 223,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.6800799,
#   'longitude': -73.96832,
#   'name': "Cataldo's Restaurant",
#   'review_count': 258,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7651362,
#   'longitude': -73.8182876,
#   'name': 'Xtra Cheese Pizza',
#   'review_count': 132,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7454863,
#   'longitude': -73.9993392,
#   'name': 'Zia Maria - Chelsea',
#   'review_count': 310,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7439080906573,
#   'longitude': -73.9997112751007,
#   'name': "Joe's Pizza",
#   'review_count': 91,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.778337,
#   'longitude': -73.956623,
#   'name': 'Famous Famiglia Pizzeria',
#   'review_count': 98,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.617634,
#   'longitude': -73.931864,
#   'name': "Frank's Pizza",
#   'review_count': 137,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.650639,
#   'longitude': -73.83808,
#   'name': 'Divino Pizzeria Restaurant',
#   'review_count': 179,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6203982490085,
#   'longitude': -73.9172416847543,
#   'name': 'Original Pizza',
#   'review_count': 213,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.8301996389829,
#   'longitude': -73.9473449424522,
#   'name': 'Bono Trattoria',
#   'review_count': 356,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.75522,
#   'longitude': -73.98539,
#   'name': "Paul's On Times Square",
#   'review_count': 342,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72713,
#   'longitude': -73.9802799,
#   'name': 'Gnocco',
#   'review_count': 570,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.74516465585421,
#   'longitude': -73.975869,
#   'name': 'Garlic New York Pizza Bar',
#   'review_count': 491,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.741315,
#   'longitude': -73.917955,
#   'name': "Giovanni's Pizza Restaurant",
#   'review_count': 23,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.710117,
#   'longitude': -74.005661,
#   'name': "Rosella's Pizzeria",
#   'review_count': 270,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.854131,
#   'longitude': -73.886601,
#   'name': "Antonio's Trattoria",
#   'review_count': 1022,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.774562,
#   'longitude': -73.958892,
#   'name': 'Don Filippo Restaurant',
#   'review_count': 192,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.655174,
#   'longitude': -73.887446,
#   'name': 'Royal Pizzeria Restaurant',
#   'review_count': 9,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.752672726751186,
#   'longitude': -73.9891,
#   'name': 'Zeppola Bakery',
#   'review_count': 99,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.74367,
#   'longitude': -73.95345,
#   'name': 'sLICe LIC',
#   'review_count': 454,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.713912316525,
#   'longitude': -73.98921028220892,
#   'name': 'Lower East Side Pizza',
#   'review_count': 80,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.76177,
#   'longitude': -73.96575,
#   'name': 'Patsy’s Pizzeria',
#   'review_count': 461,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.737136,
#   'longitude': -73.7777141,
#   'name': 'Fresh Meadows Pizzeria',
#   'review_count': 173,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.732218,
#   'longitude': -73.68728,
#   'name': "Umberto's Pizzeria & Restaurant",
#   'review_count': 899,
#   'rating': 3.5,
# ...
#   'name': 'Sunny John Pizzeria',
#   'review_count': 40,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.68418116575449,
#   'longitude': -74.0018677711487,
#   'name': "Ferdinando's Focacceria",
#   'review_count': 215,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.74727,
#   'longitude': -73.97721,
#   'name': "Libretto's Pizzeria",
#   'review_count': 229,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.6821365356445,
#   'longitude': -73.9957122802734,
#   'name': 'Enoteca on Court',
#   'review_count': 260,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.71873,
#   'longitude': -73.9909,
#   'name': 'Empanada Mama L.E.S',
#   'review_count': 912,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.71322,
#   'longitude': -73.94911,
#   'name': "Sal's Pizzeria",
#   'review_count': 201,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.80894,
#   'longitude': -73.94496,
#   'name': 'Babbalucci',
#   'review_count': 470,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.75362,
#   'longitude': -73.6933947,
#   'name': 'Iavarone Italian Kitchen & Pizzeria',
#   'review_count': 279,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7987564,
#   'longitude': -73.9673846,
#   'name': 'Buchetta Brick Oven Pizza',
#   'review_count': 223,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.8435944773229,
#   'longitude': -73.8359653694324,
#   'name': "Frank's Pizzeria",
#   'review_count': 119,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.74237,
#   'longitude': -73.9176,
#   'name': 'La Bella Pizzeria',
#   'review_count': 47,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7517,
#   'longitude': -73.97432,
#   'name': '99 Cent Fresh Pizza',
#   'review_count': 286,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.66341,
#   'longitude': -73.99468,
#   'name': 'Brothers Pizza',
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.849121,
#   'longitude': -73.854675,
#   'name': "Emilio's of Morris Park",
#   'review_count': 213,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6701,
#   'longitude': -74.11265,
#   'name': "Denapoli's Pizza",
#   'review_count': 18,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.69442,
#   'longitude': -74.21642,
#   'name': 'Comet Pizzeria',
#   'review_count': 24,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.820069,
#   'longitude': -73.977234,
#   'name': 'Pizza Club',
#   'review_count': 247,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.6808917,
#   'longitude': -73.8426307,
#   'name': 'Ozone Pizza',
#   'review_count': 129,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.68387,
#   'longitude': -74.10426,
#   'name': 'Café Bello',
#   'review_count': 196,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.73863,
#   'longitude': -73.98727,
#   'name': 'Bravo Pizza',
#   'review_count': 131,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.7025733903159,
#   'longitude': -73.9698984748688,
#   'name': 'Rooftop Reds',
#   'review_count': 169,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.81648,
#   'longitude': -74.00288,
#   'name': 'Garden Pizza',
#   'review_count': 118,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.91832,
#   'longitude': -73.89684,
#   'name': "Gino's Pizzeria",
#   'review_count': 89,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.777568,
#   'longitude': -73.949218,
#   'name': 'Gotham Pizza',
#   'review_count': 139,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.8141969,
#   'longitude': -73.9598383,
#   'name': '314 Pizza Pasta & Cocktail Bar',
#   'review_count': 133,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.58615,
#   'longitude': -73.95235,
#   'name': 'Delmar Pizzeria',
#   'review_count': 253,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.677328,
#   'longitude': -73.997972,
#   'name': 'Frankies 457 Spuntino',
#   'review_count': 889,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.648513,
#   'longitude': -74.138297,
#   'name': 'Mama Rosa Cucina Pizzeria',
#   'review_count': 78,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7637252807617,
#   'longitude': -73.9921112060547,
#   'name': "New York Sal's Pizza",
#   'review_count': 77,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.6049099,
#   'longitude': -73.9977399,
#   'name': 'La Bella Pizza',
#   'review_count': 48,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.74450383,
#   'longitude': -73.65620367,
#   'name': "Luigi's Pizzeria of Mineola",
#   'review_count': 209,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.677583,
#   'longitude': -73.958857,
#   'name': 'Pasha Pizza',
#   'review_count': 67,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.836067,
#   'longitude': -74.1135663,
#   'name': "Ferazzoli's Italian Kitchen",
#   'review_count': 279,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72879,
#   'longitude': -74.00165,
#   'name': 'Dante',
#   'review_count': 599,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.77223189920225,
#   'longitude': -73.95566751924939,
#   'name': 'Uva Next Door',
#   'review_count': 75,
#   'rating': 4.0,
#   'price': '$$$'},
#  {'latitude': 40.76031458977054,
#   'longitude': -74.41667337483189,
#   'name': 'Tino’s Artisan Pizza',
#   'review_count': 59,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.90454,
#   'longitude': -74.21047,
#   'name': "Dominick's Pizzeria",
#   'review_count': 87,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.886035,
#   'longitude': -73.909539,
#   'name': 'Bella Notte',
#   'review_count': 231,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.74505372839559,
#   'longitude': -73.9788811,
#   'name': "Sticky's Finger Joint",
#   'review_count': 469,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.71666591260819,
#   'longitude': -73.95125357171182,
#   'name': "Bamonte's",
#   'review_count': 422,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7023136,
#   'longitude': -73.9007353,
#   'name': "Burek's Pizza",
#   'review_count': 34,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.729684,
#   'longitude': -73.957827,
#   'name': 'Franklin Pizza',
#   'review_count': 63,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.754764,
#   'longitude': -73.987443,
#   'name': '99 Cent Fresh Pizza',
#   'review_count': 305,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 41.05372,
#   'longitude': -73.54162,
#   'name': 'Sally’s Apizza',
#   'review_count': 138,
#   'rating': 3.0,
#   'price': '$$'},
#  {'latitude': 40.74766471982,
#   'longitude': -73.9849202334881,
#   'name': 'Little Italy Pizza',
#   'review_count': 459,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.90906,
#   'longitude': -74.09188,
#   'name': 'Grumpy Pizza Co.',
#   'review_count': 49,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.746294,
#   'longitude': -73.917768,
#   'name': "Skillman's Famous Pizza and Coffee Shop",
#   'review_count': 61,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7436186428648,
#   'longitude': -74.0288001558544,
#   'name': "Giovanni's Pizzeria & Restaurant",
#   'review_count': 152,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.90044,
#   'longitude': -74.0363,
#   'name': "Brooklyn's Brick Oven Pizzeria",
#   'review_count': 438,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.752435,
#   'longitude': -74.001475,
#   'name': 'Mercado Little Spain',
#   'review_count': 521,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.722237,
#   'longitude': -73.9875259,
#   'name': "Katz's Delicatessen",
#   'review_count': 14880,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7137,
#   'longitude': -73.99197,
#   'name': 'E Broadway Pizza',
#   'review_count': 12,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.8960026,
#   'longitude': -73.8054674,
#   'name': 'Four Corners Pizza',
#   'review_count': 66,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.72345561427916,
#   'longitude': -74.3072699945952,
#   'name': 'Vinnie’s Brick Oven Pan Pizza',
#   'review_count': 50,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.7398,
#   'longitude': -73.788972,
#   'name': 'Brother’s Pizzeria',
#   'review_count': 278,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.551229,
#   'longitude': -74.150126,
#   'name': "Mimmo's Brick Oven Pizza and Trattoria",
#   'review_count': 194,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.761082,
#   'longitude': -73.997872,
#   'name': 'La Vela Dining & Bar',
#   'review_count': 190,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.59034,
#   'longitude': -73.9732499,
#   'name': 'Knapp Pizza II',
#   'review_count': 182,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7189526,
#   'longitude': -73.9555245,
#   'name': "Fedoroff's Roast Pork",
#   'review_count': 360,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.76765,
#   'longitude': -73.92056,
#   'name': 'Mela Pizza House',
#   'review_count': 63,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.77907,
#   'longitude': -73.91439,
#   'name': 'Mia Pizza',
#   'review_count': 131,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.627949,
#   'longitude': -74.023567,
#   'name': 'Bay Ridge Pizza',
#   'review_count': 214,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.5840481565596,
#   'longitude': -73.9396257952115,
#   'name': 'Roll-N-Roaster',
#   'review_count': 1342,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.758194,
#   'longitude': -73.980905,
#   'name': 'The Elgin',
#   'review_count': 256,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.732283,
#   'longitude': -73.999284,
#   'name': 'Babbo',
#   'review_count': 2589,
#   'rating': 4.0,
#   'price': '$$$$'},
#  {'latitude': 40.7229424,
#   'longitude': -73.8741563,
#   'name': "Gino's of Middle Village Pizza",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7662427,
#   'longitude': -73.98124349999999,
#   'name': "Jeannie's",
#   'review_count': 24,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017,
#   'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7428322,
#   'longitude': -73.9930115,
#   'name': 'Great Burrito',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.846881,
#   'longitude': -74.082494,
#   'name': "Adrian's Jersey Pizza",
#   'review_count': 244,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.588756,
#   'longitude': -74.095153,
#   'name': "Lee's Tavern",
#   'review_count': 634,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.8228,
#   'longitude': -73.84867,
#   'name': 'Pizza Italia',
#   'review_count': 47,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.78152,
#   'longitude': -73.94886,
#   'name': 'Delizia 92',
#   'review_count': 301,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.758194,
#   'longitude': -73.980905,
#   'name': 'The Elgin',
#   'review_count': 256,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.732283,
#   'longitude': -73.999284,
#   'name': 'Babbo',
#   'review_count': 2589,
#   'rating': 4.0,
#   'price': '$$$$'},
#  {'latitude': 40.7229424,
#   'longitude': -73.8741563,
#   'name': "Gino's of Middle Village Pizza",
#   'review_count': 80,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7662427,
#   'longitude': -73.98124349999999,
#   'name': "Jeannie's",
#   'review_count': 24,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.8292327076197,
#   'longitude': -73.8757006824017,
#   'name': 'Yankee J-Z Pizza',
#   'review_count': 64,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.7428322,
#   'longitude': -73.9930115,
#   'name': 'Great Burrito',
#   'review_count': 265,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.7151444,
#   'longitude': -74.0080027,
#   'name': 'Dona Bella Pizza',
#   'review_count': 202,
#   'rating': 3.0,
#   'price': '$'},
#  {'latitude': 40.846881,
#   'longitude': -74.082494,
#   'name': "Adrian's Jersey Pizza",
#   'review_count': 244,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.588756,
#   'longitude': -74.095153,
#   'name': "Lee's Tavern",
#   'review_count': 634,
#   'rating': 4.5,
#   'price': '$$'},
#  {'latitude': 40.8228,
#   'longitude': -73.84867,
#   'name': 'Pizza Italia',
#   'review_count': 47,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.78152,
#   'longitude': -73.94886,
#   'name': 'Delizia 92',
#   'review_count': 301,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7389111700125,
#   'longitude': -73.9999985153443,
#   'name': 'Coppelia',
#   'review_count': 1519,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7668561,
#   'longitude': -73.789851,
#   'name': 'Graziella Pizza & Restaurant',
#   'review_count': 134,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7185198905011,
#   'longitude': -73.99744725889785,
#   'name': 'Zia Maria Little Italy',
#   'review_count': 346,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.80816,
#   'longitude': -74.00796,
#   'name': 'Roma Pizzeria',
#   'review_count': 51,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7502738,
#   'longitude': -73.9909354,
#   'name': 'Little Italy Pizza',
#   'review_count': 174,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.5850368,
#   'longitude': -73.8190164,
#   'name': "Whit's End",
#   'review_count': 321,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.6454519,
#   'longitude': -74.0101539,
#   'name': "Charlie's Pizzeria",
#   'review_count': 26,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.707555318913,
#   'longitude': -74.006898168681,
#   'name': "Harry's Italian",
#   'review_count': 630,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.75756463099685,
#   'longitude': -73.98608001118411,
#   'name': "Junior's Restaurant",
#   'review_count': 5636,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.7447371960713,
#   'longitude': -73.9880339428782,
#   'name': 'Ulivo',
#   'review_count': 368,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.74455,
#   'longitude': -74.03579,
#   'name': 'Dozzino',
#   'review_count': 335,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.67959,
#   'longitude': -73.99518,
#   'name': 'Giardini Pizzeria & Restaurant',
#   'review_count': 106,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.770352,
#   'longitude': -73.904303,
#   'name': 'Porto Bello',
#   'review_count': 226,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.662972,
#   'longitude': -74.197951,
#   'name': "Eli's Pizza Pasta",
#   'review_count': 120,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.730685,
#   'longitude': -73.985502,
#   'name': "John's of 12th Street",
#   'review_count': 852,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.673224,
#   'longitude': -73.869757,
#   'name': "Original Napoli's Pizza",
#   'review_count': 50,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.7049434740873,
#   'longitude': -74.0048825740814,
#   'name': 'Industry Kitchen',
#   'review_count': 898,
#   'rating': 3.5,
#   'price': '$$'},
#  {'latitude': 40.83062,
#   'longitude': -73.69017,
#   'name': "Carlo's Pizza",
#   'review_count': 82,
#   'rating': 4.5,
#   'price': '$'},
#  {'latitude': 40.8419,
#   'longitude': -73.93892,
#   'name': 'Famous Famiglia',
#   'review_count': 85,
#   'rating': 2.5,
#   'price': '$'},
#  {'latitude': 40.7010231018066,
#   'longitude': -73.9226455688477,
#   'name': "Tony's and Orazio Pizza",
#   'review_count': 161,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.711191,
#   'longitude': -73.961424,
#   'name': 'Pies-n-Thighs',
#   'review_count': 3165,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.67868,
#   'longitude': -73.86793,
#   'name': "Joe's Pizzeria",
#   'review_count': 33,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.833345,
#   'longitude': -74.09726,
#   'name': "Ralph's Italian Restaurant & Pizzeria",
#   'review_count': 74,
#   'rating': 3.5,
#   'price': '$'},
#  {'latitude': 40.5446448928292,
#   'longitude': -74.276500967984,
#   'name': "Strawberry's Pub & Pizza",
#   'review_count': 382,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.726783,
#   'longitude': -73.894276,
#   'name': "Patrizia's Of Maspeth",
#   'review_count': 263,
#   'rating': 4.0,
#   'price': '$$'},
#  {'latitude': 40.72175,
#   'longitude': -73.98864,
#   'name': 'Una Pizza Napoletana',
#   'review_count': 152,
#   'rating': 3.5,
#   'price': '$$$'},
#  {'latitude': 40.61318,
#   'longitude': -73.939567,
#   'name': 'Quentin Pizzeria & Restaurant',
#   'review_count': 30,
#   'rating': 4.0,
#   'price': '$'},
#  {'latitude': 40.681713,
#   'longitude': -73.83699,
#   'name': "Romeo's Pizzeria",
#   'review_count': 102,
#   'rating': 4.0,
#   'price': '$'}]

# %% [markdown]
# ## 3. Perform Exploratory Analysis
#
# Take the businesses from the previous question and do an initial exploratory analysis. We have provided some plots for you to interpret:

# %%
# Run this cell without changes
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline

fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(16, 5))

# Plot distribution of number of reviews
all_review_counts = [x["review_count"] for x in full_dataset]
ax1.hist(all_review_counts)
ax1.set_title("Review Count Distribution")
ax1.set_xlabel("Number of Reviews")
ax1.set_ylabel("Number of Businesses")

# Plot rating distribution
all_ratings = [x["rating"] for x in full_dataset]
rating_counter = Counter(all_ratings)
rating_keys = sorted(rating_counter.keys())
ax2.bar(rating_keys, [rating_counter[key] for key in rating_keys])
ax2.set_title("Rating Distribution")
ax2.set_xlabel("Rating")
ax2.set_ylabel("Number of Businesses")

# Plot price distribution
all_prices = [x["price"].replace("$", r"\$") for x in full_dataset]
price_counter = Counter(all_prices)
price_keys = sorted(price_counter.keys())
ax3.bar(price_keys, [price_counter[key] for key in price_keys])
ax3.set_title("Price Distribution")
ax3.set_xlabel("Price Category")
ax3.set_ylabel("Number of Businesses");

# %% [markdown]
# Describe the distributions displayed above and interpret them in the context of your query. (Your answer may differ from the solution branch depending on your query.)

# %%
# Replace None with appropriate text
"""
Reviews are very right skewed, but I think the main problem here is really 
that you should have had more bins to unpack that one big column.

Ratings are left skewed, leading to the impression that most restaurants are
a 4 out of 5. Which is probably because people are more likely to leave
reviews for things they like.

Prices are left skewed, which makes sense. Most things are cheap.
"""

# %% [markdown]
# In the cell below, we also plot the rating distributions by price. In this setup, a price of one dollar sign is "lower price" and everything else is "higher price".

# %%
# Run this cell without changes

higher_price = []
lower_price = []
for row in full_dataset:
    if row["price"] == "$":
        lower_price.append(row["rating"])
    else:
        higher_price.append(row["rating"])
        
fig, ax = plt.subplots()

ax.hist([higher_price, lower_price], label=["higher price", "lower price"], density=True)

ax.legend();

# %% [markdown]
# Is a higher price associated with a higher rating? (No need for any additional math/statistics, just interpret what you see in the plot.)

# %%
# Replace None with appropriate text
"""
There appears to be a reasonably strong correlation between price and rating.
"""

# %% [markdown]
# Finally, let's look at ratings vs. review counts:

# %%
# Run this cell without changes
fig, ax = plt.subplots(figsize=(16,5))

ax.scatter(all_review_counts, all_ratings, alpha=0.2)
ax.set_xlabel("Number of Reviews")
ax.set_ylabel("Rating")
# "zoom in" to a subset of review counts
ax.set_xlim(left=0, right=1000);

# %% [markdown]
# Is a higher number of reviews associated with a higher rating?

# %%
# Replace None with appropriate text
"""
It's a bit hard to tell, but since 3.5 and 4.5 seems to be very comparable,
I'd say no.
"""

# %% [markdown]
# ## 4. Create a Folium Map
#
# Make a map using Folium of the businesses you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.
#
# You can center the map around the latitude and longitude of the first item in `full_dataset`.

# %%
# Replace None with appropriate code

# Import the library
import folium

# Set up center latitude and longitude
center_lat = 40.730610
center_long = -73.99

# Initialize map with center lat and long
yelp_map = folium.Map([center_lat, center_long], zoom_start=12)

# Adjust this limit to see more or fewer businesses
limit=100

for b in full_dataset[:limit]:
    # Extract information about business
    lat = b["latitude"]
    long = b["longitude"]
    name = b["name"]
    rating = b["rating"]
    price = b["price"]
    details = "{}\nPrice: {} Rating:{}".format(name,price,rating)
    
    # Create popup with relevant details
    popup = folium.Popup(details)
    
    # Create marker with relevant lat/long and popup
    marker = folium.Marker([lat, long], popup=popup)
    
    marker.add_to(yelp_map)
    
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
